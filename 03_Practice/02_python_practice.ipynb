# %%
text = "Coding"
print(text[2])
# Out:
# d

# %%
text = "Coding"
print(text[1:5])
# Out:
# odin

# %%
name = "Ana"
age = 20
print(f"My name is {name} and age after 5 years is {age + 5}")
# Out:
# My name is Ana and age after 5 years is 25

# %%
#Write a program that asks for a name and prints:

name = input("What is your name?")

print(f"Hello {name}!")
# Out:
# Hello !

# %%
#Write a program that asks for a word and prints its first and last character.

word = input("Enter a word:")

print(f"The first character is {word[0]} and the last character is {word[-1]}")
# Out:
# The first character is j and the last character is u

# %%
x = "Hello"
print(x[1])
# Out:
# e

# %%
#Write a program that takes a number as input and prints double of it.

number = int(input("Enter a number:"))

print(number*2)
# Out:
# 14

# %%
# Write a program that takes a word and prints:
# the length of the word
# the first character
# the last character

word = input("Enter a word:")
print(f"The length of word is {len(word)}")
print(f"The first character is {word[0]}")
print(f"The last character is {word[-1]}")
# Out:
# The length of word is 8
# The first character is e
# The last character is t

# %%
# A list stores multiple items in one variable.

# Why lists matter:

# store multiple values together
# easy to update
# used in almost every real program

numbers = [10, 20, 30]
names = ["Ana", "Bob", "Cody"]
mixed = [1, "hi", True]

# %%
fruits = ["apple", "banana", "mango"]
print(fruits[0])
fruits.append("orange")
print(fruits)
# Out:
# apple
# ['apple', 'banana', 'mango', 'orange']

# %%
fruits = ["apple", "banana"]
print(fruits[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 fruits = ["apple", "banana"]
# ----> 2 print(fruits[2])
#
# IndexError: list index out of range

# %%
nums = [1, 2, 3, 4]
print(nums[2])
# Out:
# 3

# %%
items = ["a", "b", "c"]
items.append("d")
print(items)
# Out:
# ['a', 'b', 'c', 'd']

# %%
# Write a program that:
# takes 3 numbers as input
# stores them in a list
# prints the sum

#solution: 
# numbers need to be taken as input
# store all these numbers into list
# should print sum of all these numbers

num1 = int(input("Enter a first number:"))
num2 = int(input("Enter a second number"))
num3 = int(input("Enter a third number:"))

numbers = [num1, num2, num3]

print(sum(numbers))
# Out:
# 15

# %%
# Write a program that:
# stores your 3 favorite fruits in a list
# prints the first and last fruit

fruits = ["apple","mango","orange"]

print(fruits[0])

print(fruits[-1])
# Out:
# apple
# orange

# %%
values = [10, 20, 30]
print(values[2])
# Out:
# 30

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
fruits = ["apple", "mango", "orange"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# mango
# orange

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
nums = [2, 4, 6]
for n in nums:
    print(n * 2)
# Out:
# 4
# 8
# 12

# %%
# Write a program that prints numbers from 1 to 5.

for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Write a program that takes a list of 3 numbers and prints each number doubled.

num1 = int(input("Enter a first number:"))
num2 = int(input("Enter a second number"))
num3 = int(input("Enter a third number:"))

numbers = [num1, num2, num3]

for num in numbers:
    print(num*2)
# Out:
# 8
# 10
# 16

# %%
for i in range(3):
    print("Hello")
# Out:
# Hello
# Hello
# Hello
